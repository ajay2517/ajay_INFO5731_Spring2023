# %% [markdown]
# <a href="https://colab.research.google.com/github/ajay2517/ajay_INFO5731_Spring2023/blob/main/INFO5731_excercise_two_Spring2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The second In-class-exercise (02/07/2023, 40 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points): Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
'''
Please write you answer here:

The very fascinating practical  question that  I have in mind is to find all the top good movies or to grade a good movies in imdb as we  can see lot of  different opinions,understanding and different ratings and reviews for one  particular movie.
The data  i need to collect is as described below:
1)movie name
2)Initial release 
3)director name 
4)stars(main crew)

100 or 1000 data samples are enough for this analyis to caulculate the relationship between the salary and mental well being.below are the Steps needed  for collecting and saving the data:
 
1)preparing a survey questions that includes all the fields that we required.
2)scatter the survey answers based on the  movie reviewers.
3)get the responses and collect them in a xl sheet or database.
4)preprocess the data using big data techniques  to  ensure it is in the correct format for analysis.

'''

# %% [markdown]
# Question 2 (10 points): Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):


from bs4 import BeautifulSoup
import requests
import re


link = 'http://www.imdb.com/chart/top' ## Download IMDB's Top 1000 data
responseofrequest = requests.get(link)
soup = BeautifulSoup(responseofrequest.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

imdb = []


for index in range(0, len(movies)):
  
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino
# 3 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger
# 4 - The Godfather Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman
# 9 - The Lord of the Rings: The Fellowship of the Ring (2001) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen
# ...

# %% [markdown]
# Question 3 (10 points): Write python code to collect 1000 articles from Google Scholar (https://scholar.google.com/), Microsoft Academic (https://academic.microsoft.com/home), or CiteSeerX (https://citeseerx.ist.psu.edu/index), or Semantic Scholar (https://www.semanticscholar.org/), or ACM Digital Libraries (https://dl.acm.org/) with the keyword "information retrieval". The articles should be published in the last 10 years (2012-2022).
#
# The following information of the article needs to be collected:
#
# (1) Title
#
# (2) Venue/journal/conference being published
#
# (3) Year
#
# (4) Authors
#
# (5) Abstract

# %%
# You code here (Please add comments in the code):
import urllib.request
from bs4 import BeautifulSoup
import json

with urllib.request.urlopen('https://api.semanticscholar.org/v1/paper/10.1145/2348283.2348407') as file:
    web_page = file.read()
    soup = BeautifulSoup(web_page)
#     print (soup.prettify()) - to check the valid one.
    text = soup.p.text
    print(text)
    with open('2348407-meta.txt', 'w') as outfile:
        json.dump(text, outfile)
# Out:
# {"abstract":"Typically, every part in most coherent text has some plausible reason for its presence, some function that it performs to the overall semantics of the text. Rhetorical relations, e.g. contrast, cause, explanation, describe how the parts of a text are linked to each other. Knowledge about this so-called discourse structure has been applied successfully to several natural language processing tasks. This work studies the use of rhetorical relations for Information Retrieval (IR): Is there a correlation between certain rhetorical relations and retrieval performance? Can knowledge about a document's rhetorical relations be useful to IR? We present a language model modification that considers rhetorical relations when estimating the relevance of a document to a query. Empirical evaluation of different versions of our model on TREC settings shows that certain rhetorical relations can benefit retrieval effectiveness notably (>10% in mean average precision over a state-of-the-art
# ...

# %% [markdown]
# Question 4 (10 points): Write python code to collect 1000 posts from Twitter, or Facebook, or Instagram. You can either use hashtags, keywords, user_name, user_id, or other information to collect the data.
#
# The following information needs to be collected:
#
# (1) User_name
#
# (2) Posted time
#
# (3) Text

# %%
# You code here (Please add comments in the code):
import os
import tweepy as tw
import pandas as pd

l= '2Em7SxlX9jPMfL4x97r3zMO0x'
m= 'sVbJzekKuiAgq83Y7gCwNVbSowqQokGVzWexKHl2cXIPceWtSd'
n= '1439767876962029572-uUMt8oWRyzj9ilE5zk4uYbL93sCMPT'
access= 'oydIGymn9bS767FVEMawE9GyGAnMmBJfaY2XXKmHnmliF'

authorize = tw.OAuthHandler(l, m)
authorize.set_access_token(n, access)
i = tw.API(authorize, wait_on_rate_limit=True)

w = "#love"
d = "2023-01-10"

twee = tw.Cursor(i.search,
              q=w,
              lang="en",
              since=d).items(1000)

[i.text for i in twee]
# Out:
# ["RT @RappCatsAdopt: #GoodMorning! Look who decided to get brave &amp; explore the intake room! It's newbie Dot!💖#cats #cat #pets #AdoptDontShop…",
#  'RT @ClayPuff: Happy Hearts day everyone!....\nHeart shape Apple Pie,\nSome Chocolates,\nMarshmallows,\nAnd Candies...\n#love #chocolates #candie…',
#  'You want to cry like a damn baby? Pull out the old VHS recording of your parents’ wedding. #love #blessed #wedding #lovestory',
#  '#Saint February 14 : St. Valentine, a Martyr who Secretly Helped #Couples Marry and the Patron of #Love and… https://t.co/wkL8J8P4fO',
#  "I absolutely love Linkin Park. So to hear a new song with Chester singing honestly broke me!! It's beautiful. It in… https://t.co/JsBIvtMnIH",
#  'When u know ur power —  game is changing 🔥\n\n#concert #bikers #rockandroll #powerful #fun #happy #girl… https://t.co/pkoxhIRsiK',
# ...
